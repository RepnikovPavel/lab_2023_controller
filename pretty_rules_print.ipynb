# %%
rules_dict = {
    1: {
        'IF': ['theta is PB','omega is NB'],
        'THEN': ['F is ZE']
    },
    2: {
        'IF': ['theta is PB','omega is NM'],
        'THEN': ['F is PS']
    },
    3: {
        'IF': ['theta is PB','omega is NS'],
        'THEN': ['F is PM']
    },
    4: {
        'IF': ['theta is PB','omega is ZE'],
        'THEN': ['F is PB']
    },
    5: {
        'IF': ['theta is PB','omega is PS'],
        'THEN': ['F is PB']
    },
    6: {
        'IF': ['theta is PB','omega is PM'],
        'THEN': ['F is PB']
    },
    7: {
        'IF': ['theta is PB','omega is PB'],
        'THEN': ['F is PB']
    },
    8: {
        'IF': ['theta is PM','omega is NB'],
        'THEN': ['F is NS']
    },
    9: {
        'IF': ['theta is PM','omega is NM'],
        'THEN': ['F is ZE']
    },
    10: {
        'IF': ['theta is PM','omega is NS'],
        'THEN': ['F is PS']
    },
    11: {
        'IF': ['theta is PM','omega is ZE'],
        'THEN': ['F is PM']
    },
    12: {
        'IF': ['theta is PM','omega is PS'],
        'THEN': ['F is PB']
    },
    13: {
        'IF': ['theta is PM','omega is PM'],
        'THEN': ['F is PB']
    },
    14: {
        'IF': ['theta is PM','omega is PB'],
        'THEN': ['F is PB']
    },
    15: {
        'IF': ['theta is PS','omega is NB'],
        'THEN': ['F is NM']
    },
    16: {
        'IF': ['theta is PS','omega is NM'],
        'THEN': ['F is NS']
    },
    17: {
        'IF': ['theta is PS','omega is NS'],
        'THEN': ['F is ZE']
    },
    18: {
        'IF': ['theta is PS','omega is ZE'],
        'THEN': ['F is PS']
    },
    19: {
        'IF': ['theta is PS','omega is PS'],
        'THEN': ['F is PM']
    },
    20: {
        'IF': ['theta is PS','omega is PM'],
        'THEN': ['F is PB']
    },
    21: {
        'IF': ['theta is PS','omega is PB'],
        'THEN': ['F is PB']
    },
    22: {
        'IF': ['theta is ZE','omega is NB'],
        'THEN': ['F is NB']
    },
    23: {
        'IF': ['theta is ZE','omega is NM'],
        'THEN': ['F is NM']
    },
    24: {
        'IF': ['theta is ZE','omega is NS'],
        'THEN': ['F is NS']
    },
    25: {
        'IF': ['theta is ZE','omega is ZE'],
        'THEN': ['F is ZE']
    },
    26: {
        'IF': ['theta is ZE','omega is PS'],
        'THEN': ['F is PS']
    },
    27: {
        'IF': ['theta is ZE','omega is PM'],
        'THEN': ['F is PM']
    },
    28: {
        'IF': ['theta is ZE','omega is PB'],
        'THEN': ['F is PB']
    },
    29: {
        'IF': ['theta is NS','omega is NB'],
        'THEN': ['F is NB']
    },
    30: {
        'IF': ['theta is NS','omega is NM'],
        'THEN': ['F is NB']
    },
    31: {
        'IF': ['theta is NS','omega is NS'],
        'THEN': ['F is NM']
    },
    32: {
        'IF': ['theta is NS','omega is ZE'],
        'THEN': ['F is NS']
    },
    33: {
        'IF': ['theta is NS','omega is PS'],
        'THEN': ['F is ZE']
    },
    34: {
        'IF': ['theta is NS','omega is PM'],
        'THEN': ['F is PS']
    },
    35: {
        'IF': ['theta is NS','omega is PB'],
        'THEN': ['F is PM']
    },
    36: {
        'IF': ['theta is NM','omega is NB'],
        'THEN': ['F is NB']
    },
    37: {
        'IF': ['theta is NM','omega is NM'],
        'THEN': ['F is NB']
    },
    38: {
        'IF': ['theta is NM','omega is NS'],
        'THEN': ['F is NB']
    },
    39: {
        'IF': ['theta is NM','omega is ZE'],
        'THEN': ['F is NM']
    },
    40: {
        'IF': ['theta is NM','omega is PS'],
        'THEN': ['F is NS']
    },
    41: {
        'IF': ['theta is NM','omega is PM'],
        'THEN': ['F is ZE']
    },
    42: {
        'IF': ['theta is NM','omega is PB'],
        'THEN': ['F is PS']
    },
    43: {
        'IF': ['theta is NB','omega is NB'],
        'THEN': ['F is NB']
    },
    44: {
        'IF': ['theta is NB','omega is NM'],
        'THEN': ['F is NB']
    },
    45: {
        'IF': ['theta is NB','omega is NS'],
        'THEN': ['F is NB']
    },
    46: {
        'IF': ['theta is NB','omega is ZE'],
        'THEN': ['F is NB']
    },
    47: {
        'IF': ['theta is NB','omega is PS'],
        'THEN': ['F is NM']
    },
    48: {
        'IF': ['theta is NB','omega is PM'],
        'THEN': ['F is NS']
    },
    49: {
        'IF': ['theta is NB','omega is PB'],
        'THEN': ['F is ZE']
    }
}

# %%
for k in rules_dict:
    a =  rules_dict[k]['IF'][0]
    a_ = a.split(' ')
    a_[1]  = chr(92) + 'text{ ' +a_[1]+ ' ' + a_[2] + '}'
    a_[0] = '$' + chr(92)+ a_[0] + '$' 
    a = ' '.join(a_[:2])
    b = rules_dict[k]['IF'][1]

    b_ = b.split(' ')
    b_[1]  = chr(92) + 'text{ ' +b_[1]+ ' ' + b_[2] + '}'
    b_[0] =  '$' + chr(92)+ b_[0] + '$' 
    b = ' '.join(b_[:2])

    c = rules_dict[k]['THEN'][0]

    c_ = c.split(' ')
    c_[1]  = chr(92) + 'text{ ' +c_[1]+ ' ' + c_[2] + '}'
    c = ' '.join(c_[:2])

    IF = chr(92)+'text{ IF }'
    THEN = chr(92)+'text{ THEN }'
    AND = chr(92)+'text{ AND }'
    print(f'{k} & {IF} {a} {AND} {b} {THEN} {c} \\\\')
    print(chr(92)+'hline')
# Out:
# 1 & \text{ IF } $\theta$ \text{ is PB} \text{ AND } $\omega$ \text{ is NB} \text{ THEN } F \text{ is ZE} \\
# \hline
# 2 & \text{ IF } $\theta$ \text{ is PB} \text{ AND } $\omega$ \text{ is NM} \text{ THEN } F \text{ is PS} \\
# \hline
# 3 & \text{ IF } $\theta$ \text{ is PB} \text{ AND } $\omega$ \text{ is NS} \text{ THEN } F \text{ is PM} \\
# \hline
# 4 & \text{ IF } $\theta$ \text{ is PB} \text{ AND } $\omega$ \text{ is ZE} \text{ THEN } F \text{ is PB} \\
# \hline
# 5 & \text{ IF } $\theta$ \text{ is PB} \text{ AND } $\omega$ \text{ is PS} \text{ THEN } F \text{ is PB} \\
# \hline
# 6 & \text{ IF } $\theta$ \text{ is PB} \text{ AND } $\omega$ \text{ is PM} \text{ THEN } F \text{ is PB} \\
# \hline
# 7 & \text{ IF } $\theta$ \text{ is PB} \text{ AND } $\omega$ \text{ is PB} \text{ THEN } F \text{ is PB} \\
# \hline
# 8 & \text{ IF } $\theta$ \text{ is PM} \text{ AND } $\omega$ \text{ is NB} \text{ THEN } F \text{ is NS} \\
# \hline
# ...
